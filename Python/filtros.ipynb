# %% [markdown]
# ## Ejemplo 5: Filtros
#
# ### 1. Objetivos:
#     - Aprender cómo funcionan los filtros
#     - Aplicar varios filtros para verlos en acción
#
# ---
#
# ### 2. Desarrollo:

# %%
import pandas as pd

# %%
df = pd.read_csv('new_york_times_bestsellers-dirty.csv', index_col=0)
df.head(3)
# Out:
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                          description      publisher  \
# 0  Descr: Aliens have taken control of the minds ...  Little, Brown
# 1  Descr: A woman's happy marriage is shaken when...   St. Martin's
# 2  Descr: A Massachusetts state investigator and ...         Putnam
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95

# %% [markdown]
# Digamos que queremos todos los registros donde el nombre del autor empiece con 'R'. Primero, usamos `operadores de comparación` (o en este caso, el método `str.startswith(-patrón-)`) para obtener nuestro filtro:

# %%
# crea tu condición aquí
df['author'].str.startswith('R')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 3027    False
# 3028    False
# 3029    False
# 3030    False
# 3031    False
# Name: author, Length: 2266, dtype: bool

# %% [markdown]
# Lo que obtenemos de regreso es una `Serie` con la misma longitud que la `Serie` original. Se aplicó el método o la comparación a cada elemento de la `Serie` original. Estos métodos o comparaciones regresan `True` o `False` dependiendo de cada valor. La `Serie` resultante acumula los `Trues` y `Falses` que obtengamos de la comparación o de la aplicación del método.
#
# Después, al pasar este filtro al `operador de indexación` del `DataFrame`, todas las filas a las que les corresponda un `True` se mantienen, mientras que las filas a las que les corresponde un `False` se dejan fuera del subconjunto resultante:
#
# `dataframe[ -serie índice para filtrado- ]`

# %%
# crea tu filtro aquí
df[df['author'].str.startswith('R')].head(3)
# Out:
#                                     amazon_product_url          author  \
# 79   http://www.amazon.com/Chasing-Darkness-Elvis-N...    Robert Crais
# 94   http://www.amazon.com/Chasing-Darkness-Elvis-N...    Robert Crais
# 110  http://www.amazon.com/Killer-View-Fleming-Ridl...  Ridley Pearson
#
#                                            description         publisher  \
# 79   Descr: he Los Angeles private eye Elvis Cole r...  Simon & Schuster
# 94   Descr: Is the Los Angeles private eye Elvis Co...  Simon & Schuster
# 110  Descr: A sheriff in Sun Valley, Idaho, investi...            Putnam
#
#                 title                       oid bestsellers_date.numberLong  \
# 79   CHASING DARKNESS  5b4aa4ead3089013507db209         2008-07-05 00:00:00
# 94   CHASING DARKNESS  5b4aa4ead3089013507db221         2008-07-12 00:00:00
# 110       KILLER VIEW  5b4aa4ead3089013507db239         2008-07-19 00:00:00
#
#      published_date.numberLong rank.numberInt  rank_last_week.numberInt  \
# 79               1216512000000              7                         0
# 94               1217116800000             11                         7
# 110              1217721600000             15                         0
#
#      weeks_on_list.numberInt  price.numberDouble
# 79                         1               25.95
# 94                         2               25.95
# 110                        1               24.95

# %% [markdown]
# Podemos también guardar nuestras condiciones en variables y después utilizarlos, por ejemplo, encuentra todas las producciones cuyo precio es mayor a 20:

# %%
mayor_a_20 = df['price.numberDouble'] > 20

# %%
df[mayor_a_20].head(3)
# Out:
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                          description      publisher  \
# 0  Descr: Aliens have taken control of the minds ...  Little, Brown
# 1  Descr: A woman's happy marriage is shaken when...   St. Martin's
# 2  Descr: A Massachusetts state investigator and ...         Putnam
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95

# %% [markdown]
# Podemos incluso aplicar dos o más filtros utilizando `operadores lógicos`. En este caso, nuestro operador `and` se representa con un `&` y el operador `or` se representa con `|`.
#
# Así que podemos obtener todas las producciones con rango 1 y que además cuyo precio sea mayor a 20:

# %%
rank_numero_uno = df['rank.numberInt'] == '1'

# %%
df[mayor_a_20 & rank_numero_uno].shape
# Out:
# (135, 12)

# %%
df.dtypes
# Out:
# amazon_product_url              object
# author                          object
# description                     object
# publisher                       object
# title                           object
# oid                             object
# bestsellers_date.numberLong     object
# published_date.numberLong        int64
# rank.numberInt                  object
# rank_last_week.numberInt         int64
# weeks_on_list.numberInt          int64
# price.numberDouble             float64
# dtype: object

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 5: Filtros
#
# ### 1. Objetivos:
#     - Practicar el uso de filtros para la obtención de subconjuntos de datos
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Filtrando por fechas, booleanos y valores numéricos
#
# Vamos a trabajar con el mismo dataset que guardaste del Reto anterior. Este Reto consiste en los siguiente:
#
# Usando filtros, crea 3 subconjuntos de datos:
#
# 1. Un subconjunto llamado `df_hazardous` que contenga sólo los records que correspondan a los objetos donde `is_potentially_hazardous_asteroid` sea `True` (o `1`).
# 2. Un subconjunto llamado `df_greater_than_1000` que contenga sólo los records donde el `estimated_diameter.meters.estimated_diameter_max` sea mayor a 1000 metros.
# 3. Un subconjunto llamado `df_february` que contenga sólo los records que pertenezcan exactamente al mes de Febrero de 1995. Recuerda que los datos en la columna `epoch_date_close_approach` están en milisegundos.

# %%
import pandas as pd

# %%
df_reto_5 = pd.read_csv('near_earth_objects-jan_feb_1995-reto_4.csv', index_col=0)
df_reto_5.head(3)
# Out:
#                       id_name  is_potentially_hazardous_asteroid  \
# 0  2154652-154652 (2004 EP20)                                  0
# 1           3153509-(2003 HM)                                  1
# 2          3837644-(2019 AY3)                                  0
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         46.190746
#
#    estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                       1081.533507          1995-01-07
# 1                                        215.794305          1995-01-07
# 2                                        103.285648          1995-01-07
#
#   epoch_date_close_approach orbiting_body  \
# 0       1995-01-07 08:33:00         Earth
# 1       1995-01-07 15:09:00         Earth
# 2       1995-01-07 21:25:00         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
# 2                                22.478615
#
#    relative_velocity.kilometers_per_hour  \
# 0                           58114.308667
# 1                           44463.757734
# 2                           80923.015021
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
# 2  Near Earth asteroid orbits similar to that of ...  3837644
#
#                  name  relative_velocity.kilometers_per_minute  \
# 0  154652 (2004 EP20)                               968.571811
# 1           (2003 HM)                               741.062629
# 2          (2019 AY3)                              1348.716917
#
#    proportion_of_max_diameter_to_earth
# 0                             0.000085
# 1                             0.000017
# 2                             0.000008

# %%
# tu código aquí
df_hazardous = df_reto_5[df_reto_5['is_potentially_hazardous_asteroid'] == 1]
df_greater_than_1000 = df_reto_5[df_reto_5['estimated_diameter.meters.estimated_diameter_max'] > 1000]
df_february = df_reto_5[df_reto_5['epoch_date_close_approach'] >'1995-01-31 23:59:59']

# %%
df_hazardous.head()
# Out:
#                        id_name  is_potentially_hazardous_asteroid  \
# 1            3153509-(2003 HM)                                  1
# 6   2446862-446862 (2001 VB76)                                  1
# 15         3766463-(2017 AY13)                                  1
# 16          3342323-(2006 SF6)                                  1
# 17  2452807-452807 (2006 KV89)                                  1
#
#     estimated_diameter.meters.estimated_diameter_min  \
# 1                                          96.506147
# 6                                         231.502122
# 15                                        133.215567
# 16                                        278.326768
# 17                                        146.067964
#
#     estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 1                                         215.794305          1995-01-07
# 6                                         517.654482          1995-01-08
# 15                                        297.879063          1995-01-03
# 16                                        622.357573          1995-01-03
# 17                                        326.617897          1995-01-03
#
#    epoch_date_close_approach orbiting_body  \
# 1        1995-01-07 15:09:00         Earth
# 6        1995-01-08 09:13:00         Earth
# 15       1995-01-03 01:31:00         Earth
# 16       1995-01-03 08:00:00         Earth
# 17       1995-01-03 03:33:00         Earth
#
#     relative_velocity.kilometers_per_second  \
# 1                                 12.351044
# 6                                  7.590711
# 15                                14.235092
# 16                                 5.248637
# 17                                 5.201917
#
#     relative_velocity.kilometers_per_hour  \
# 1                            44463.757734
# 6                            27326.560174
# 15                           51246.330073
# 16                           18895.092087
# 17                           18726.902889
#
#                               orbit_class_description       id  \
# 1   Near Earth asteroid orbits which cross the Ear...  3153509
# 6   Near Earth asteroid orbits similar to that of ...  2446862
# 15  Near Earth asteroid orbits which cross the Ear...  3766463
# 16  Near Earth asteroid orbits which cross the Ear...  3342323
# 17  Near Earth asteroid orbits which cross the Ear...  2452807
#
#                   name  relative_velocity.kilometers_per_minute  \
# 1            (2003 HM)                               741.062629
# 6   446862 (2001 VB76)                               455.442670
# 15         (2017 AY13)                               854.105501
# 16          (2006 SF6)                               314.918201
# 17  452807 (2006 KV89)                               312.115048
#
#     proportion_of_max_diameter_to_earth
# 1                              0.000017
# 6                              0.000041
# 15                             0.000023
# 16                             0.000049
# 17                             0.000026

# %%
df_greater_than_1000.head(8)
# Out:
#                         id_name  is_potentially_hazardous_asteroid  \
# 0    2154652-154652 (2004 EP20)                                  0
# 5            3824107-(2018 JB3)                                  0
# 8           3645123-(2013 NX23)                                  0
# 13     2137062-137062 (1998 WM)                                  0
# 23   2138947-138947 (2001 BA40)                                  0
# 53  2002062-2062 Aten (1976 AA)                                  0
# 58   2152964-152964 (2000 GP82)                                  0
# 77          3643994-(2013 LV28)                                  0
#
#     estimated_diameter.meters.estimated_diameter_min  \
# 0                                         483.676488
# 5                                         802.703167
# 8                                         483.676488
# 13                                       1272.198785
# 23                                        506.471459
# 53                                       1010.543415
# 58                                        766.575574
# 77                                        461.907460
#
#     estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 0                                        1081.533507          1995-01-07
# 5                                        1794.898848          1995-01-08
# 8                                        1081.533507          1995-01-05
# 13                                       2844.722965          1995-01-06
# 23                                       1132.504611          1995-01-04
# 53                                       2259.643771          1995-01-12
# 58                                       1714.115092          1995-01-13
# 77                                       1032.856481          1995-01-11
#
#    epoch_date_close_approach orbiting_body  \
# 0        1995-01-07 08:33:00         Earth
# 5        1995-01-08 10:54:00         Earth
# 8        1995-01-05 22:31:00         Earth
# 13       1995-01-06 04:47:00         Earth
# 23       1995-01-04 12:16:00         Earth
# 53       1995-01-12 01:44:00         Earth
# 58       1995-01-13 12:45:00         Earth
# 77       1995-01-11 20:09:00         Earth
#
#     relative_velocity.kilometers_per_second  \
# 0                                 16.142864
# 5                                 32.160753
# 8                                 21.605199
# 13                                 9.604877
# 23                                10.155092
# 53                                10.324052
# 58                                10.734807
# 77                                25.508069
#
#     relative_velocity.kilometers_per_hour  \
# 0                            58114.308667
# 5                           115778.710301
# 8                            77778.715682
# 13                           34577.556386
# 23                           36558.329695
# 53                           37166.587108
# 58                           38645.303568
# 77                           91829.048391
#
#                               orbit_class_description       id  \
# 0   Near Earth asteroid orbits similar to that of ...  2154652
# 5   Near Earth asteroid orbits which cross the Ear...  3824107
# 8   Near Earth asteroid orbits similar to that of ...  3645123
# 13  Near Earth asteroid orbits similar to that of ...  2137062
# 23  Near Earth asteroid orbits which cross the Ear...  2138947
# 53  Near Earth asteroid orbits similar to that of ...  2002062
# 58  Near Earth asteroid orbits which cross the Ear...  2152964
# 77  Near Earth asteroid orbits which cross the Ear...  3643994
#
#                    name  relative_velocity.kilometers_per_minute  \
# 0    154652 (2004 EP20)                               968.571811
# 5            (2018 JB3)                              1929.645172
# 8           (2013 NX23)                              1296.311928
# 13     137062 (1998 WM)                               576.292606
# 23   138947 (2001 BA40)                               609.305495
# 53  2062 Aten (1976 AA)                               619.443118
# 58   152964 (2000 GP82)                               644.088393
# 77          (2013 LV28)                              1530.484140
#
#     proportion_of_max_diameter_to_earth
# 0                              0.000085
# 5                              0.000141
# 8                              0.000085
# 13                             0.000223
# 23                             0.000089
# 53                             0.000177
# 58                             0.000135
# 77                             0.000081

# %%
df_february
# Out:
#                          id_name  is_potentially_hazardous_asteroid  \
# 156           3405174-(2008 ED8)                                  0
# 157          3792431-(2017 XT61)                                  0
# 158         3511508-(2010 CW180)                                  0
# 159          3781883-(2017 SN14)                                  0
# 160     2403039-403039 (2008 AE)                                  0
# ..                           ...                                ...
# 296  2311554-311554 (2006 BQ147)                                  0
# 297  2267136-267136 (2000 EF104)                                  0
# 298           3360486-(2006 WE4)                                  0
# 299           3656919-(2014 BG3)                                  0
# 300           3803762-(2018 GY4)                                  0
#
#      estimated_diameter.meters.estimated_diameter_min  \
# 156                                         44.111820
# 157                                         60.891262
# 158                                        253.837029
# 159                                        461.907460
# 160                                        305.179233
# ..                                                ...
# 296                                        483.676488
# 297                                        441.118200
# 298                                        441.118200
# 299                                        160.160338
# 300                                        421.264611
#
#      estimated_diameter.meters.estimated_diameter_max close_approach_date  \
# 156                                         98.637028          1995-02-04
# 157                                        136.157002          1995-02-04
# 158                                        567.596853          1995-02-05
# 159                                       1032.856481          1995-02-05
# 160                                        682.401509          1995-02-05
# ..                                                ...                 ...
# 296                                       1081.533507          1995-02-21
# 297                                        986.370281          1995-02-21
# 298                                        986.370281          1995-02-21
# 299                                        358.129403          1995-02-21
# 300                                        941.976306          1995-02-21
#
#     epoch_date_close_approach orbiting_body  \
# 156       1995-02-04 09:06:00         Earth
# 157       1995-02-04 00:37:00         Earth
# 158       1995-02-05 10:31:00         Earth
# 159       1995-02-05 18:17:00         Earth
# 160       1995-02-05 12:05:00         Earth
# ..                        ...           ...
# 296       1995-02-21 17:29:00         Earth
# 297       1995-02-21 04:17:00         Earth
# 298       1995-02-21 15:44:00         Earth
# 299       1995-02-21 12:08:00         Earth
# 300       1995-02-21 12:54:00         Earth
#
#      relative_velocity.kilometers_per_second  \
# 156                                13.317721
# 157                                 9.359303
# 158                                11.657770
# 159                                15.857860
# 160                                 6.078498
# ..                                       ...
# 296                                15.474761
# 297                                16.180392
# 298                                15.106140
# 299                                20.343173
# 300                                29.732426
#
#      relative_velocity.kilometers_per_hour  \
# 156                           47943.796767
# 157                           33693.492339
# 158                           41967.973343
# 159                           57088.295988
# 160                           21882.592129
# ..                                     ...
# 296                           55709.139812
# 297                           58249.410194
# 298                           54382.104639
# 299                           73235.423517
# 300                          107036.733058
#
#                                orbit_class_description       id  \
# 156  Near Earth asteroid orbits similar to that of ...  3405174
# 157  Near Earth asteroid orbits which cross the Ear...  3792431
# 158  An asteroid orbit contained entirely within th...  3511508
# 159  Near Earth asteroid orbits similar to that of ...  3781883
# 160  An asteroid orbit contained entirely within th...  2403039
# ..                                                 ...      ...
# 296  Near Earth asteroid orbits similar to that of ...  2311554
# 297  Near Earth asteroid orbits similar to that of ...  2267136
# 298  Near Earth asteroid orbits which cross the Ear...  3360486
# 299  An asteroid orbit contained entirely within th...  3656919
# 300  Near Earth asteroid orbits similar to that of ...  3803762
#
#                     name  relative_velocity.kilometers_per_minute  \
# 156           (2008 ED8)                               799.063279
# 157          (2017 XT61)                               561.558206
# 158         (2010 CW180)                               699.466222
# 159          (2017 SN14)                               951.471600
# 160     403039 (2008 AE)                               364.709869
# ..                   ...                                      ...
# 296  311554 (2006 BQ147)                               928.485664
# 297  267136 (2000 EF104)                               970.823503
# 298           (2006 WE4)                               906.368411
# 299           (2014 BG3)                              1220.590392
# 300           (2018 GY4)                              1783.945551
#
#      proportion_of_max_diameter_to_earth
# 156                             0.000008
# 157                             0.000011
# 158                             0.000045
# 159                             0.000081
# 160                             0.000054
# ..                                   ...
# 296                             0.000085
# 297                             0.000077
# 298                             0.000077
# 299                             0.000028
# 300                             0.000074
#
# [134 rows x 14 columns]
